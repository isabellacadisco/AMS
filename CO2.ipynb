# %%
#import 
import pandas as pd

# %%
#read data
meta_country = pd.read_csv('data\Metadata_Country.csv')

# %%
meta_country
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
meta_country.drop("Unnamed: 5",axis=1)
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
meta_indicator = pd.read_csv('data\Metadata_Indicator.csv')

# %%
meta_indicator
# Out:
#    INDICATOR_CODE      INDICATOR_NAME  \
# 0  EN.ATM.CO2E.KT  CO2 emissions (kt)
#
#                                          SOURCE_NOTE  \
# 0  Carbon dioxide emissions are those stemming fr...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  Climate Watch. 2020. GHG Emissions. Washington...         NaN

# %%
meta_indicator.drop("Unnamed: 4",axis=1)
# Out:
#    INDICATOR_CODE      INDICATOR_NAME  \
# 0  EN.ATM.CO2E.KT  CO2 emissions (kt)
#
#                                          SOURCE_NOTE  \
# 0  Carbon dioxide emissions are those stemming fr...
#
#                                  SOURCE_ORGANIZATION
# 0  Climate Watch. 2020. GHG Emissions. Washington...

# %%
CO2 = pd.read_csv('data\CO2.csv')

# %%
CO2
# Out:
#                     Country Name Country Code      Indicator Name  \
# 0                          Aruba          ABW  CO2 emissions (kt)
# 1    Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                    Afghanistan          AFG  CO2 emissions (kt)
# 3     Africa Western and Central          AFW  CO2 emissions (kt)
# 4                         Angola          AGO  CO2 emissions (kt)
# ..                           ...          ...                 ...
# 261                       Kosovo          XKX  CO2 emissions (kt)
# 262                  Yemen, Rep.          YEM  CO2 emissions (kt)
# 263                 South Africa          ZAF  CO2 emissions (kt)
# 264                       Zambia          ZMB  CO2 emissions (kt)
# 265                     Zimbabwe          ZWE  CO2 emissions (kt)
#
#      Indicator Code  1960  1961  1962  1963  1964  1965  ...           2013  \
# 0    EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...            NaN
# ...

# %%
CO2.columns.str.match("Unnamed")
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True])

# %%
CO2.drop("Unnamed: 66",axis=1)
# Out:
#                     Country Name Country Code      Indicator Name  \
# 0                          Aruba          ABW  CO2 emissions (kt)
# 1    Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                    Afghanistan          AFG  CO2 emissions (kt)
# 3     Africa Western and Central          AFW  CO2 emissions (kt)
# 4                         Angola          AGO  CO2 emissions (kt)
# ..                           ...          ...                 ...
# 261                       Kosovo          XKX  CO2 emissions (kt)
# 262                  Yemen, Rep.          YEM  CO2 emissions (kt)
# 263                 South Africa          ZAF  CO2 emissions (kt)
# 264                       Zambia          ZMB  CO2 emissions (kt)
# 265                     Zimbabwe          ZWE  CO2 emissions (kt)
#
#      Indicator Code  1960  1961  1962  1963  1964  1965  ...           2012  \
# 0    EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...            NaN
# ...

# %%
CO2["Country Code"].is_unique
# Out:
# True

# %%
meta_country["Country Code"].is_unique
# Out:
# True

# %%
# keep just 2018
#così ho droppato tutto da CO2
#CO2.drop(CO2.columns.difference(['Country Name','Country Code', 'Indicator Name', 'Indicator Code', '2018']), 1, inplace=True)

CO2_2018 = CO2[['Country Name','Country Code', 'Indicator Name', 'Indicator Code', '2018']]

# %%
CO2_2018
# Out:
#                     Country Name Country Code      Indicator Name  \
# 0                          Aruba          ABW  CO2 emissions (kt)
# 1    Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                    Afghanistan          AFG  CO2 emissions (kt)
# 3     Africa Western and Central          AFW  CO2 emissions (kt)
# 4                         Angola          AGO  CO2 emissions (kt)
# ..                           ...          ...                 ...
# 261                       Kosovo          XKX  CO2 emissions (kt)
# 262                  Yemen, Rep.          YEM  CO2 emissions (kt)
# 263                 South Africa          ZAF  CO2 emissions (kt)
# 264                       Zambia          ZMB  CO2 emissions (kt)
# 265                     Zimbabwe          ZWE  CO2 emissions (kt)
#
#      Indicator Code           2018
# 0    EN.ATM.CO2E.KT            NaN
# 1    EN.ATM.CO2E.KT  590040.005282
# 2    EN.ATM.CO2E.KT    6070.000172
# ...

# %%
meta_country = meta_country.loc[:, ~meta_country.columns.str.contains('^Unnamed')]

# %%
meta_country
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
CO2_2018.join(meta_country.set_index('Country Code'), on='Country Code')
# Out:
#                     Country Name Country Code      Indicator Name  \
# 0                          Aruba          ABW  CO2 emissions (kt)
# 1    Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                    Afghanistan          AFG  CO2 emissions (kt)
# 3     Africa Western and Central          AFW  CO2 emissions (kt)
# 4                         Angola          AGO  CO2 emissions (kt)
# ..                           ...          ...                 ...
# 261                       Kosovo          XKX  CO2 emissions (kt)
# 262                  Yemen, Rep.          YEM  CO2 emissions (kt)
# 263                 South Africa          ZAF  CO2 emissions (kt)
# 264                       Zambia          ZMB  CO2 emissions (kt)
# 265                     Zimbabwe          ZWE  CO2 emissions (kt)
#
#      Indicator Code           2018                      Region  \
# 0    EN.ATM.CO2E.KT            NaN   Latin America & Caribbean
# ...

# %%
CO2_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   2018            239 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 10.5+ KB

# %%
print(CO2_2018.isnull().sum())
# Out:
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 2018              27
# dtype: int64

# %%
CO2_2018_complete = CO2_2018.dropna()

# %%
CO2_2018_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 1 to 265
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    239 non-null    object
#  1   Country Code    239 non-null    object
#  2   Indicator Name  239 non-null    object
#  3   Indicator Code  239 non-null    object
#  4   2018            239 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 11.2+ KB
