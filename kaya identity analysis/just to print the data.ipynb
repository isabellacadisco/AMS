# %%
import pandas as pd
import numpy as np

# %%
dudu = pd.read_excel("data_reduce_filled.xlsx")

# %%
dudu
# Out:
#     Country Code           Country Name  \
# 0            AFG            Afghanistan
# 1            ALB                Albania
# 2            DZA                Algeria
# 3            ASM         American Samoa
# 4            AGO                 Angola
# ..           ...                    ...
# 195          VIR  Virgin Islands (U.S.)
# 196          PSE     West Bank and Gaza
# 197          YEM            Yemen, Rep.
# 198          ZMB                 Zambia
# 199          ZWE               Zimbabwe
#
#      Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]  \
# 0                                               30.900
# 1                                               79.800
# 2                                               99.600
# 3                                               81.168
# 4                                               49.100
# ..                                                 ...
# ...

# %%
income_group = pd.DataFrame(dudu['Income Group'])

# %%
income_group
# Out:
#     Income Group
# 0              L
# 1             UM
# 2             UM
# 3             UM
# 4             LM
# ..           ...
# 195            H
# 196           LM
# 197            L
# 198           LM
# 199           LM
#
# [200 rows x 1 columns]

# %%
dudu = dudu.drop(['Income Group'], axis = 1)

# %%
dudu.insert(2, 'Income Group', income_group)

# %%
data = dudu

# %%
data
# Out:
#     Country Code           Country Name Income Group  \
# 0            AFG            Afghanistan            L
# 1            ALB                Albania           UM
# 2            DZA                Algeria           UM
# 3            ASM         American Samoa           UM
# 4            AGO                 Angola           LM
# ..           ...                    ...          ...
# 195          VIR  Virgin Islands (U.S.)            H
# 196          PSE     West Bank and Gaza           LM
# 197          YEM            Yemen, Rep.            L
# 198          ZMB                 Zambia           LM
# 199          ZWE               Zimbabwe           LM
#
#      Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]  \
# 0                                               30.900
# 1                                               79.800
# 2                                               99.600
# 3                                               81.168
# ...
