# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("retained_vars.csv")

# %%
data
# Out:
#     Country Code                                Country Name  \
# 0            AFG                                 Afghanistan
# 1            ALB                                     Albania
# 2            DZA                                     Algeria
# 3            ASM                              American Samoa
# 4            AND                                     Andorra
# ..           ...                                         ...
# 261          SSF                          Sub-Saharan Africa
# 262          SSA  Sub-Saharan Africa (excluding high income)
# 263          TSS   Sub-Saharan Africa (IDA & IBRD countries)
# 264          UMC                         Upper middle income
# 265          WLD                                       World
#
#      Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]  \
# 0                                            30.900000
# 1                                            79.800000
# ...
