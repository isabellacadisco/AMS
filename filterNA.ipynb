# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("wdi2.xlsx")

# %%
data
# Out:
#      Time Time Code                                Country Name Country Code  \
# 0    2021    YR2021                                 Afghanistan          AFG
# 1    2021    YR2021                                     Albania          ALB
# 2    2021    YR2021                                     Algeria          DZA
# 3    2021    YR2021                              American Samoa          ASM
# 4    2021    YR2021                                     Andorra          AND
# ..    ...       ...                                         ...          ...
# 261  2021    YR2021                          Sub-Saharan Africa          SSF
# 262  2021    YR2021  Sub-Saharan Africa (excluding high income)          SSA
# 263  2021    YR2021   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 264  2021    YR2021                         Upper middle income          UMC
# 265  2021    YR2021                                       World          WLD
#
# ...

# %%
data = data.replace(to_replace='None', value=np.NaN)

# %%
data
# Out:
#      Time Time Code                                Country Name Country Code  \
# 0    2021    YR2021                                 Afghanistan          AFG
# 1    2021    YR2021                                     Albania          ALB
# 2    2021    YR2021                                     Algeria          DZA
# 3    2021    YR2021                              American Samoa          ASM
# 4    2021    YR2021                                     Andorra          AND
# ..    ...       ...                                         ...          ...
# 261  2021    YR2021                          Sub-Saharan Africa          SSF
# 262  2021    YR2021  Sub-Saharan Africa (excluding high income)          SSA
# 263  2021    YR2021   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 264  2021    YR2021                         Upper middle income          UMC
# 265  2021    YR2021                                       World          WLD
#
# ...

# %%
data.isna()
# Out:
#       Time  Time Code  Country Name  Country Code  \
# 0    False      False         False         False
# 1    False      False         False         False
# 2    False      False         False         False
# 3    False      False         False         False
# 4    False      False         False         False
# ..     ...        ...           ...           ...
# 261  False      False         False         False
# 262  False      False         False         False
# 263  False      False         False         False
# 264  False      False         False         False
# 265  False      False         False         False
#
#      Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# ...

# %%
data.isnull()
# Out:
#       Time  Time Code  Country Name  Country Code  \
# 0    False      False         False         False
# 1    False      False         False         False
# 2    False      False         False         False
# 3    False      False         False         False
# 4    False      False         False         False
# ..     ...        ...           ...           ...
# 261  False      False         False         False
# 262  False      False         False         False
# 263  False      False         False         False
# 264  False      False         False         False
# 265  False      False         False         False
#
#      Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# ...

# %%
print(data.isnull().sum())
# Out:
# Time                                                                                                                 0
# Time Code                                                                                                            0
# Country Name                                                                                                         0
# Country Code                                                                                                         0
# Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]                              266
#                                                                                                                   ...
# Women who believe a husband is justified in beating his wife when she refuses sex with him (%) [SG.VAW.REFU.ZS]    263
# Women who were first married by age 15 (% of women ages 20-24) [SP.M15.2024.FE.ZS]                                 261
# ...

# %%
result = data.isna().mean()

# %%
print(result)
# Out:
# Time                                                                                                               0.000000
# Time Code                                                                                                          0.000000
# Country Name                                                                                                       0.000000
# Country Code                                                                                                       0.000000
# Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]                              1.000000
#                                                                                                                      ...
# Women who believe a husband is justified in beating his wife when she refuses sex with him (%) [SG.VAW.REFU.ZS]    0.988722
# ...

# %%
#remove columns with >5% NA
data_filtered95 = data.loc[:,result < .05]
data_filtered95
# Out:
#      Time Time Code                                Country Name Country Code  \
# 0    2021    YR2021                                 Afghanistan          AFG
# 1    2021    YR2021                                     Albania          ALB
# 2    2021    YR2021                                     Algeria          DZA
# 3    2021    YR2021                              American Samoa          ASM
# 4    2021    YR2021                                     Andorra          AND
# ..    ...       ...                                         ...          ...
# 261  2021    YR2021                          Sub-Saharan Africa          SSF
# 262  2021    YR2021  Sub-Saharan Africa (excluding high income)          SSA
# 263  2021    YR2021   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 264  2021    YR2021                         Upper middle income          UMC
# 265  2021    YR2021                                       World          WLD
#
# ...

# %%
list(data_filtered95.columns)
# Out:
# ['Time',
#  'Time Code',
#  'Country Name',
#  'Country Code',
#  'Age dependency ratio (% of working-age population) [SP.POP.DPND]',
#  'Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]',
#  'Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]',
#  'Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]',
#  'Net migration [SM.POP.NETM]',
#  'Population ages 00-04, female (% of female population) [SP.POP.0004.FE.5Y]',
#  'Population ages 00-04, male (% of male population) [SP.POP.0004.MA.5Y]',
#  'Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]',
#  'Population ages 0-14, female [SP.POP.0014.FE.IN]',
#  'Population ages 0-14, female (% of female population) [SP.POP.0014.FE.ZS]',
#  'Population ages 0-14, male [SP.POP.0014.MA.IN]',
#  'Population ages 0-14, male (% of male population) [SP.POP.0014.MA.ZS]',
#  'Population ages 0-14, total [SP.POP.0014.TO]',
# ...

# %%
# WRITE ON TXT
#with open("col_few_na.txt", "w") as output:
 #   output.write(str(list(data.columns)))

# %%
#remove columns with >10% NA
data_filtered90 = data.loc[:,result < .1]
data_filtered90
# Out:
#      Time Time Code                                Country Name Country Code  \
# 0    2021    YR2021                                 Afghanistan          AFG
# 1    2021    YR2021                                     Albania          ALB
# 2    2021    YR2021                                     Algeria          DZA
# 3    2021    YR2021                              American Samoa          ASM
# 4    2021    YR2021                                     Andorra          AND
# ..    ...       ...                                         ...          ...
# 261  2021    YR2021                          Sub-Saharan Africa          SSF
# 262  2021    YR2021  Sub-Saharan Africa (excluding high income)          SSA
# 263  2021    YR2021   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 264  2021    YR2021                         Upper middle income          UMC
# 265  2021    YR2021                                       World          WLD
#
# ...

# %%
list(data_filtered90.columns)
# Out:
# ['Time',
#  'Time Code',
#  'Country Name',
#  'Country Code',
#  'Age dependency ratio (% of working-age population) [SP.POP.DPND]',
#  'Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]',
#  'Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]',
#  'Compulsory education, duration (years) [SE.COM.DURS]',
#  'Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]',
#  'Foreign direct investment, net inflows (BoP, current US$) [BX.KLT.DINV.CD.WD]',
#  'GDP (constant 2015 US$) [NY.GDP.MKTP.KD]',
#  'GDP (current US$) [NY.GDP.MKTP.CD]',
#  'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]',
#  'GDP per capita (constant 2015 US$) [NY.GDP.PCAP.KD]',
#  'GDP per capita (current US$) [NY.GDP.PCAP.CD]',
#  'GDP per capita growth (annual %) [NY.GDP.PCAP.KD.ZG]',
#  'Immunization, DPT (% of children ages 12-23 months) [SH.IMM.IDPT]',
#  'Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]',
# ...

# %%
list(data.columns)
# Out:
# ['Time',
#  'Time Code',
#  'Country Name',
#  'Country Code',
#  'Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]',
#  'Access to clean fuels and technologies for cooking, rural (% of rural population) [EG.CFT.ACCS.RU.ZS]',
#  'Access to clean fuels and technologies for cooking, urban (% of urban population) [EG.CFT.ACCS.UR.ZS]',
#  'Access to electricity (% of population) [EG.ELC.ACCS.ZS]',
#  'Access to electricity, rural (% of rural population) [EG.ELC.ACCS.RU.ZS]',
#  'Access to electricity, urban (% of urban population) [EG.ELC.ACCS.UR.ZS]',
#  'Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+) [FX.OWN.TOTL.ZS]',
#  'Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+) [FX.OWN.TOTL.FE.ZS]',
# ...

# %%
data['GDP per capita, PPP (constant 2017 international $) [NY.GDP.PCAP.PP.KD]']
# Out:
# 0       1516.305667
# 1      14516.314351
# 2      11039.805261
# 3               NaN
# 4               NaN
#            ...
# 261     3716.984459
# 262     3714.883228
# 263     3716.984459
# 264    18192.840970
# 265    16997.107189
# Name: GDP per capita, PPP (constant 2017 international $) [NY.GDP.PCAP.PP.KD], Length: 266, dtype: float64

# %%
#remove columns with >20% NA
data_filtered80 = data.loc[:,result < .2]
print(list(data_filtered80.columns))

print(len(list(data_filtered80.columns)))
# Out:
# ['Time', 'Time Code', 'Country Name', 'Country Code', 'Age dependency ratio (% of working-age population) [SP.POP.DPND]', 'Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]', 'Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]', 'Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]', 'Agriculture, forestry, and fishing, value added (annual % growth) [NV.AGR.TOTL.KD.ZG]', 'Agriculture, forestry, and fishing, value added (constant 2015 US$) [NV.AGR.TOTL.KD]', 'Agriculture, forestry, and fishing, value added (current US$) [NV.AGR.TOTL.CD]', 'Cereal production (metric tons) [AG.PRD.CREL.MT]', 'Cereal yield (kg per hectare) [AG.YLD.CREL.KG]', 'Compulsory education, duration (years) [SE.COM.DURS]', 'Diabetes prevalence (% of population ages 20 to 79) [SH.STA.DIAB.ZS]', 'Employment to population ratio, 15+, female (%) (modeled ILO estimate) [SL.EMP.TOTL.SP.FE.ZS]', 'Employment to population ratio, 15+, male (%) (modeled I
# ...

# %%
#remove columns with >30% NA
data_filtered70 = data.loc[:,result < .3]

print(list(data_filtered70.columns))

print(len(list(data_filtered70.columns)))
# Out:
# ['Time', 'Time Code', 'Country Name', 'Country Code', 'Age dependency ratio (% of working-age population) [SP.POP.DPND]', 'Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]', 'Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]', 'Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]', 'Agriculture, forestry, and fishing, value added (annual % growth) [NV.AGR.TOTL.KD.ZG]', 'Agriculture, forestry, and fishing, value added (constant 2015 US$) [NV.AGR.TOTL.KD]', 'Agriculture, forestry, and fishing, value added (current US$) [NV.AGR.TOTL.CD]', 'Automated teller machines (ATMs) (per 100,000 adults) [FB.ATM.TOTL.P5]', 'Cereal production (metric tons) [AG.PRD.CREL.MT]', 'Cereal yield (kg per hectare) [AG.YLD.CREL.KG]', 'Charges for the use of intellectual property, payments (BoP, current US$) [BM.GSR.ROYL.CD]', 'Charges for the use of intellectual property, receipts (BoP, current US$) [BX.GSR.ROYL.CD]', 'Commercial bank bra
# ...

# %%
#remove columns with >35% NA
data_filtered65 = data.loc[:,result < .35]

print(list(data_filtered65.columns))

print(len(list(data_filtered65.columns)))
# Out:
# ['Time', 'Time Code', 'Country Name', 'Country Code', 'Age dependency ratio (% of working-age population) [SP.POP.DPND]', 'Age dependency ratio, old (% of working-age population) [SP.POP.DPND.OL]', 'Age dependency ratio, young (% of working-age population) [SP.POP.DPND.YG]', 'Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]', 'Agriculture, forestry, and fishing, value added (annual % growth) [NV.AGR.TOTL.KD.ZG]', 'Agriculture, forestry, and fishing, value added (constant 2015 US$) [NV.AGR.TOTL.KD]', 'Agriculture, forestry, and fishing, value added (current LCU) [NV.AGR.TOTL.CN]', 'Agriculture, forestry, and fishing, value added (current US$) [NV.AGR.TOTL.CD]', 'Automated teller machines (ATMs) (per 100,000 adults) [FB.ATM.TOTL.P5]', 'Bank liquid reserves to bank assets ratio (%) [FD.RES.LIQU.AS.ZS]', 'Cereal production (metric tons) [AG.PRD.CREL.MT]', 'Cereal yield (kg per hectare) [AG.YLD.CREL.KG]', 'Charges for the use of intellectual property, payments (
# ...

# %%
#remove columns with >50% NA
data_filtered50 = data.loc[:,result < .5]

print(list(data_filtered50.columns))

print(len(list(data_filtered50.columns)))
# Out:
# ['Time', 'Time Code', 'Country Name', 'Country Code', 'Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+) [FX.OWN.TOTL.ZS]', 'Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+) [FX.OWN.TOTL.FE.ZS]', 'Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+) [FX.OWN.TOTL.MA.ZS]', 'Account ownership at a financial institution or with a mobile-money-service provider, older adults (% of population ages 25+) [FX.OWN.TOTL.OL.ZS]', 'Account ownership at a financial institution or with a mobile-money-service provider, poorest 40% (% of population ages 15+) [FX.OWN.TOTL.40.ZS]', 'Account ownership at a financial institution or with a mobile-money-service provider, primary education or less (% of population ages 15+) [FX.OWN.TOTL.PL.ZS]', 'Account ownership at a financial institution or with a mobile-money-
# ...

# %%
print(list(data.columns))
# Out:
# ['Time', 'Time Code', 'Country Name', 'Country Code', 'Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]', 'Access to clean fuels and technologies for cooking, rural (% of rural population) [EG.CFT.ACCS.RU.ZS]', 'Access to clean fuels and technologies for cooking, urban (% of urban population) [EG.CFT.ACCS.UR.ZS]', 'Access to electricity (% of population) [EG.ELC.ACCS.ZS]', 'Access to electricity, rural (% of rural population) [EG.ELC.ACCS.RU.ZS]', 'Access to electricity, urban (% of urban population) [EG.ELC.ACCS.UR.ZS]', 'Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+) [FX.OWN.TOTL.ZS]', 'Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+) [FX.OWN.TOTL.FE.ZS]', 'Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+) [FX.OWN.TOTL.MA.ZS]', 'Account ownershi
# ...
